# %% [markdown]
# # Starting the Game Model
#
# ### Funcionamento
#
# - eu serei o Player, ou seja, irei fazer uma jogada.
# - Após minha jogada, entra o modelo de ML
# - O modelo irá prever vitórias para ele
#
# ### Lógica a busca pela vitória
# exemplo:
#
# Turno 1 - Meu turno
#
# (1_,'_','_','_','_','_','_','_','_')  Joguei
#
# Turno 2 - Máquina
#
# Ela irá jogar o próximo valor em todas posições possíveis não ocupadas, exemplo
#
# (1_,'2','_','_','_','_','_','_','_') = 0
#
# (1_,'_','2','_','_','_','_','_','_') = 0
# .
# .
# .
# (1_,'_','_','_','_','_','_','_','2') = 0
#
# Então irá examinar... se ocorrer vitória (1) ou empate (0.5), ela joga nesta posição o 2, caso contrário, ela testa outro número
#
#
# (1_,'2','_','3','_','_','_','_','_') = 0
#
#
# (1_,'2','_','_','3','_','_','_','_') = 0
#
#  ... novamente mesma lógica
#
#
# (1_,'_','_','3','_','4','_','_','2') = <span style= 'color:red'>1</span> ... vamos dizer que deu 1 ... então ela executa a jogada na posição 2.

# %%
import pandas as pd
import numpy as np
import random

import tensorflow as tf

# %% [markdown]
# ### Load <span style="color:red">MODEL</span>

# %%
#model.save('./save_model/model.h5')
model = tf.keras.models.load_model('./save_model/model.h5')

# %% [markdown]
# ### Load <span style="color:red">WEIGHT</span>

# %%
model.load_weights('./save_weight/weight.h5')

# %%
# creating the table
def df():
    col = []
    for n in range(1,10):
        col.append(n)
    col.append('resultado')

    df = pd.DataFrame(columns=col)
    return df

# %%
def n(x): # even odd function
    
    if x%2 == 0: # Número par retorna 0
        return x%2
    else:# número impar retorna 1
        return x%2

#even_odd(2)

# %%
class ticTacToe():
    
    def __init__(self):
        
        self.df = df()
        self.pos ={
                    1:0.5,
                    2:0.5,
                    3:0.5,
                    4:0.5,
                    5:0.5,
                    6:0.5,
                    7:0.5,
                    8:0.5,
                    9:0.5,
                    'resultado':None }
        self.t = 1 # turnos
    
    def restart_df(self):
        self.df = df()
        
    
    def restart_game(self):
        self.pos ={
                    1:0.5,
                    2:0.5,
                    3:0.5,
                    4:0.5,
                    5:0.5,
                    6:0.5,
                    7:0.5,
                    8:0.5,
                    9:0.5,
                    'resultado':None }
        self.t = 1 # turnos
        
    def check_defeat(self): # player é par
        if n(self.pos[1]) == n(self.pos[2]) == n(self.pos[3]) == 1:
            return 'break'
        if n(self.pos[4]) == n(self.pos[5]) == n(self.pos[6]) == 1:
            return 'break'
        if n(self.pos[1]) == n(self.pos[4]) == n(self.pos[7]) == 1:
            return 'break'
        if n(self.pos[1]) == n(self.pos[5]) == n(self.pos[9]) == 1:
            return 'break'
        if n(self.pos[2]) == n(self.pos[5]) == n(self.pos[6]) == 1:
            return 'break'
        if n(self.pos[3]) == n(self.pos[5]) == n(self.pos[7]) == 1:
            return 'break'
        if n(self.pos[3]) == n(self.pos[6]) == n(self.pos[9]) == 1:
            return 'break'
        if n(self.pos[7]) == n(self.pos[8]) == n(self.pos[9]) == 1:
            return 'break'
        return 'continue'

    def check_victory(self): # pc é impar
        if n(self.pos[1]) == n(self.pos[2]) == n(self.pos[3]) == 0:
            return 'break'
        if n(self.pos[4]) == n(self.pos[5]) == n(self.pos[6]) == 0:
            return 'break'
        if n(self.pos[1]) == n(self.pos[4]) == n(self.pos[7]) == 0:
            return 'break'
        if n(self.pos[1]) == n(self.pos[5]) == n(self.pos[9]) == 0:
            return 'break'
        if n(self.pos[2]) == n(self.pos[5]) == n(self.pos[6]) == 0:
            return 'break'
        if n(self.pos[3]) == n(self.pos[5]) == n(self.pos[7]) == 0:
            return 'break'
        if n(self.pos[3]) == n(self.pos[6]) == n(self.pos[9]) == 0:
            return 'break'
        if n(self.pos[7]) == n(self.pos[8]) == n(self.pos[9]) == 0:
            return 'break'
        return 'continue'
    
    def check_pos_full(self): # EMPATE
        if (self.pos[1] != 0.5 
            and self.pos[2] != 0.5 
            and self.pos[3] != 0.5 
            and self.pos[4] != 0.5
            and self.pos[5] != 0.5
            and self.pos[6] != 0.5
            and self.pos[7] != 0.5
            and self.pos[8] != 0.5
            and self.pos[9] != 0.5):
            
            return 'break'
    
        return 'continue'
    
    # Agora os turnos importam, pois turno impar é player
    # turno par é máquina.
    def check_turn(self):
        if self.t == 10: # Verificar tempo/turnos (f)
            return 'break'
        return 'continue'
    
    # Chamo esse método para verificar tudo
    def check(self):
        
        # Verificar derrota
        if self.check_defeat() == 'break':
            #print('derrotado')
            self.pos['resultado'] = 0
            
            return 'break'
        
        # Verificar Vitoria
        if self.check_victory() == 'break':
            #print('vencedor')
            self.pos['resultado'] = 1
            
            return 'break'
        
        # Verificar Turno
        self.t +=1
        if self.check_turn() == 'break':
            #print('turno')
            self.pos['resultado'] = 0.5 # Empate
            
            return 'break'
        
        # Verificar Tudo
        if self.check_pos_full() == 'break':
            #print('tudo')
            self.pos['resultado'] = 0.5 # Empate
            
            return 'break'
        
        return 'continue'
    
    # Criar a Tabelas e dar appends nela
    def add_value_df(self):
        
        df_receber = pd.DataFrame( columns=list(self.pos.keys()) )
        for i in df_receber.columns:
            if i == 'resultado':
                df_receber[i] = [self.pos[i]]
            else:    
                df_receber[i] = [self.pos[int(i)]]
                
        self.df = self.df.append(df_receber,ignore_index=True)
    
    
    # Aqui eu set os numeros no braço usando INPUTS
    def player(self, player):
        if player == 'player':
            move = int(input('player: '))
            if self.pos[move] == 0.5:
                self.pos[move] = int(self.t)
            else:
                while True:
                    move = int(input('player, tente novamente: '))

                    if self.pos[move] == 0.5:
                        self.pos[move] = int(self.t)
                        break
                        
        if player == 'pc':
            move = int(input('pc: '))
            if self.pos[move] == 0.5:
                self.pos[move] = int(self.t)

            else:
                while True:
                    move = int(input('pc, tente novamente: '))

                    if self.pos[move] == 0.5:
                        self.pos[move] = int(self.t)
                        break
                        
    
    
    def sortear_pos(self): # Ganhar tempo
        livres =[n for n in list(self.pos.keys())[:-1] if list(self.pos.values())[n-1]== 0.5]

        return random.sample(livres,1)[0] # sortear 1 número dentro dos LIVRES
    
    
    
    # Aqui eu uso para deixar a rede Treinar
    def player_random(self, player):
        if player == 'player':
            move = self.sortear_pos()
            if self.pos[move] == 0.5:
                self.pos[move] = int(self.t) # add o valor do turno 
            else:
                while True:
                    move = int(input('player, tente novamente: '))

                    if self.pos[move] == 0.5:
                        self.pos[move] = int(self.t) # add o valor do turno
                        break
                        
        if player == 'pc':
            move = self.sortear_pos()
            if self.pos[move] == 0.5:
                self.pos[move] = int(self.t) # add o valor do turno

            else:
                while True:
                    move = int(input('pc, tente novamente: '))

                    if self.pos[move] == 0.5:
                        self.pos[move] = int(self.t) # add o valor do turno
                        break
    
    
        
    # RUN DE PROGRAM
    def run(self):
        
        while True:
            
            # Jogar Player
            #self.player('player')
            self.player_random('player')
             
            # Check -----------------
            if self.check() == 'break':
                break
            
            
            # Jogar PC
            #self.player('pc')
            self.player_random('pc')
             
            # Check -----------------
            if self.check() == 'break':
                break
            #------------------------
        
        
        self.add_value_df()

# %%
# Iniciar Game
game = ticTacToe()

# %%
for i in range(0,1000):
    game.restart_game()
    game.run()

# %%
game.df
# Out:
#          1    2    3    4    5    6    7    8    9 resultado
# 0        3    7    1    2  0.5    6  0.5    5    4         0
# 1        1    4    9    2  8.0    3  6.0    5    7         0
# 2      0.5    3    6    5  4.0    1  2.0  0.5  0.5         1
# 3        5    6    2    9  4.0    1  7.0    3    8         0
# 4        1    6    3    8  4.0    9  2.0    7    5         0
# 5        8    6    3    2  9.0    1  5.0    7    4         0
# 6        6    1    2    9  3.0    4  5.0    8    7       0.5
# 7        4  0.5  0.5    6  0.5    5  2.0    3    1         1
# 8        5  0.5  0.5    3  0.5    4  1.0    2  0.5         0
# 9        4    3    1    5  2.0    9  8.0    6    7         0
# 10       2  0.5    3    6  1.0  0.5  7.0    4    5         0
# 11       1    2    8    6  4.0    3  7.0    9    5         0
# 12       9    2    3    4  7.0    1  8.0    5    6       0.5
# 13       6    8    7    3  1.0    9  2.0    5    4         0
# 14       1  0.5  0.5  0.5  5.0    3  6.0    4    2         1
# 15       1  0.5  0.5    2  5.0  0.5  4.0  0.5    3         0
# 16     0.5  0.5    7    4  3.0    1  6.0    2    5         0
# 17       2    5    4    1  6.0    8  9.0    7    3         0
# 18       8    5    9    1  3.0    4  6.0    7    2       0.5
# 19       7  0.5    4    6  5.0    1  2.0  0.5    3         0
# 20       3    2  0.5    4  5.0    1  6.0  0.5    7         0
# 21       2    5    4  0.5  6.0  0.5  3.0    7    1         0
# 22       2    4    1    6  7.0  0.5  8.0    5    3         1
# 23       4    2    6    3  5.0  0.5  0.5    1  0.5         1
# 24       3    5    4    6  1.0    8  7.0    2    9         0
# 25       1    4    3    8  5.0    7  2.0    9    6       0.5
# 26       6    5    4    7  8.0    2  1.0    9    3         0
# 27       1    3  0.5    5  6.0    2  7.0  0.5    4         0
# 28       2    1    7    6  9.0    4  5.0    3    8         0
# 29       4  0.5    5    2  0.5    3  0.5  0.5    1         0
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 39970    5    7    2    4  3.0    1  0.5    6  0.5         0
# 39971    4    5    9    7  8.0    2  1.0    6    3       0.5
# 39972    3    6    9    4  5.0    8  1.0    7    2         0
# 39973    3    7    2    1  5.0  0.5  8.0    6    4         1
# 39974    1    2    3    6  9.0    8  5.0    4    7         0
# 39975    2    7    9    4  5.0    8  1.0    6    3         0
# 39976    2    1    5    6  4.0    8  3.0  0.5    7         1
# 39977  0.5    7    8    3  5.0    2  4.0    1    6         1
# 39978    8    5    1    6  0.5    3  2.0    7    4         1
# 39979  0.5    4  0.5    3  6.0    2  5.0  0.5    1         1
# 39980  0.5    4    1    2  7.0    6  3.0  0.5    5         0
# 39981    7    6    9    5  1.0    4  8.0    3    2       0.5
# 39982    1  0.5    7    5  3.0    2  4.0    6    8         1
# 39983  0.5    4  0.5    1  7.0    5  2.0    6    3         0
# 39984    6    4    2  0.5  0.5    1  3.0  0.5    5         1
# 39985    6  0.5    1    7  3.0    5  2.0    4  0.5         0
# 39986    1    2    3    5  4.0    7  8.0    9    6       0.5
# 39987    8    4  0.5    2  3.0    1  6.0    7    5         1
# 39988    2    7  0.5    6  3.0    1  0.5    5    4         0
# 39989    7    5  0.5    1  3.0    6  8.0    4    2         1
# 39990    6  0.5    1    2  5.0    4  8.0    7    3         1
# 39991    3  0.5    4    1  0.5    2  5.0  0.5  0.5         0
# 39992    5    2    9    6  4.0    1  7.0    8    3         0
# 39993    6    2    4    5  0.5    3  0.5  0.5    1         1
# 39994    8    5    1    7  4.0  0.5  3.0    2    6         1
# 39995    5    1    6    8  7.0    2  4.0    3    9         0
# 39996    6    4  0.5    2  0.5    1  3.0    7    5         0
# 39997    5  0.5    4    6  8.0    7  2.0    1    3         1
# 39998    1    4    8    6  2.0    5  3.0    9    7         0
# 39999    5    9    7    3  2.0    4  6.0    8    1         0
#
# [40000 rows x 10 columns]

# %%
# Save TABLE
#game.df.to_pickle('./dados.pkl')

# %%
#load_df = pd.read_pickle('./dados.pkl')

# %%
#load_df.drop_duplicates().reset_index().drop('index',axis=1)

# %%
# Remover Valores duplicados
dub = game.df.drop_duplicates().reset_index().drop('index',axis=1)
dub.tail()
# Out:
#        1    2    3  4    5  6    7  8  9 resultado
# 34389  5    1    6  8  7.0  2  4.0  3  9         0
# 34390  6    4  0.5  2  0.5  1  3.0  7  5         0
# 34391  5  0.5    4  6  8.0  7  2.0  1  3         1
# 34392  1    4    8  6  2.0  5  3.0  9  7         0
# 34393  5    9    7  3  2.0  4  6.0  8  1         0
