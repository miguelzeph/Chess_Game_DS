# %% [markdown]
# # Treinamento e Análise

# %%
import pandas as pd
import os
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
os.listdir('../../01_extract_data/')
# ..= voltar 1 pasta
# . = daqui pra cá
# Out:
# ['.ipynb_checkpoints', 'Start_Game_v4.ipynb', 'dados.pkl']

# %%
df = pd.read_pickle('../../01_extract_data/dados.pkl')

# %%
df.tail()
# Out:
#        1  2  3  4  5  6  7  8  9 resultado
# 79995  3  8  9  4  1  7  2  5  6      draw
# 79996  5  3  0  2  4  6  1  0  0      lost
# 79997  5  1  4  3  8  0  6  2  7      lost
# 79998  9  8  5  3  6  2  4  7  1      draw
# 79999  0  0  5  2  1  0  3  0  4       win

# %%
# Remover dados duplicados + resertar indice + dropar coluna index
#df = df.drop_duplicates().reset_index().drop('index',axis=1)
df.tail()
# Out:
#        1  2  3  4  5  6  7  8  9 resultado
# 79995  3  8  9  4  1  7  2  5  6      draw
# 79996  5  3  0  2  4  6  1  0  0      lost
# 79997  5  1  4  3  8  0  6  2  7      lost
# 79998  9  8  5  3  6  2  4  7  1      draw
# 79999  0  0  5  2  1  0  3  0  4       win

# %%
win = 1
draw = 0.5
lost = 0

# %%
def resultado_int(x):
    x=x[0]
    if x == 'win':
        return win
    if x == 'lost':
        return lost
    return draw

# %%
df['resultado'] = df[['resultado']].apply(resultado_int,axis=1)

# %% [markdown]
# # Separação dos dados

# %%
x = df.drop('resultado',axis=1)
y = df[['resultado']]


x.shape,y.shape
# Out:
# ((80000, 9), (80000, 1))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size = 0.1,
)

# %%
# RESETAR OS índices, para igualar os valores corretos de X e Y
x_train.reset_index().drop('index',axis=1)
y_train.reset_index().drop('index',axis=1)

x_test.reset_index().drop('index',axis=1)
y_test.reset_index().drop('index',axis=1)


# não sei porquê, tive que fazer essa conversão para
# o modelo ser aceito... nunca aconteceu isso antes
x_train = np.asarray(x_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
x_test = np.asarray(x_test).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)

# %%
import tensorflow as tf

# %%
x_train.shape
# Out:
# (72000, 9)

# %%
y_train.shape
# Out:
# (72000, 1)

# %%
x_train.shape[1]
# Out:
# 9

# %% [markdown]
# ### Create your model

# %%
# PODER FAZER LOAD em vez de criar novamente...

model = tf.keras.models.Sequential()

val=9


model.add(tf.keras.layers.Dense(
    units = val*20,
    activation = 'relu',
    input_shape = (x_train.shape[1],)
))


model.add(tf.keras.layers.Dense(
    units = val*20,
    activation = 'relu',
))

#model.add(tf.keras.layers.Dropout(0.1))

model.add(tf.keras.layers.Dense(
    units = val*20,
    activation = 'relu',
))




model.add(tf.keras.layers.Dense(
    units = 1,
    activation = 'sigmoid',
))

model.summary()


#model.compile(loss = 'binary_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])
#model.compile(loss = 'mean_squared_error', optimizer = 'Adamax' , metrics = ['accuracy'])
#model.compile(loss = 'mean_squared_error', optimizer = 'RMSprop' , metrics = ['accuracy'])
#model.compile(loss = 'poisson', optimizer = 'RMSprop' , metrics = ['accuracy'])
model.compile(loss ='huber_loss' ,optimizer = 'RMSprop' , metrics = ['accuracy'])

#model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])
#----------------------------------------------------------------
# Out:
# Model: "sequential_61"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_394 (Dense)            (None, 180)               1800
# _________________________________________________________________
# dense_395 (Dense)            (None, 180)               32580
# _________________________________________________________________
# dense_396 (Dense)            (None, 180)               32580
# _________________________________________________________________
# dense_397 (Dense)            (None, 1)                 181
# =================================================================
# Total params: 67,141
# Trainable params: 67,141
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Save <span style="color:blue">MODEL</span>

# %%
#model.save('../save_model/model.h5')

# %% [markdown]
# ### LOAD <span style="color:red">MODEL</span> (Pode fazer load em vez de criar)

# %%
#model = tf.keras.models.load_model('../save_model/model.h5')

# %% [markdown]
# ### LOAD <span style="color:red">WEIGHT</span>

# %%
#model.load_weights('../save_weight/weight.h5')

# %% [markdown]
# ### Calcular os pesos da rede (Se fizer o Load, não precisa)

# %%
history = model.fit(
    x_train,
    y_train,
    validation_split=0.1,# quantidade de dados que usa para treinar por época (testar)
    epochs = 100,
    verbose = 1,# Não printar
    max_queue_size=10,# fila
    batch_size=None, # Qauntidade de dados que pula
    validation_freq= 1 # Quantidade de Vezes que ele faz a Validação dos dados... exemplo de 10 em 10 épocas
)

history.history.keys()
# Out:
# Train on 64800 samples, validate on 7200 samples
# Epoch 1/100
# 64800/64800 [==============================] - 7s 103us/sample - loss: 0.0464 - accuracy: 0.7693 - val_loss: 0.0100 - val_accuracy: 0.8761
# Epoch 2/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0115 - accuracy: 0.8697 - val_loss: 0.0105 - val_accuracy: 0.8731
# Epoch 3/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0108 - accuracy: 0.8706 - val_loss: 0.0099 - val_accuracy: 0.8756
# Epoch 4/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0105 - accuracy: 0.8707 - val_loss: 0.0100 - val_accuracy: 0.8764
# Epoch 5/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0104 - accuracy: 0.8707 - val_loss: 0.0091 - val_accuracy: 0.8765
# Epoch 6/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0105 - accuracy: 0.8704 - val_loss: 0.0092 - val_accuracy: 0.8765
# Epoch 7/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0103 - accuracy: 0.8709 - val_loss: 0.0098 - val_accuracy: 0.8765
# Epoch 8/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0102 - accuracy: 0.8711 - val_loss: 0.0097 - val_accuracy: 0.8754
# Epoch 9/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0103 - accuracy: 0.8708 - val_loss: 0.0091 - val_accuracy: 0.8765
# Epoch 10/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0106 - accuracy: 0.8700 - val_loss: 0.0093 - val_accuracy: 0.8758
# Epoch 11/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0102 - accuracy: 0.8708 - val_loss: 0.0094 - val_accuracy: 0.8761
# Epoch 12/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0105 - accuracy: 0.8702 - val_loss: 0.0092 - val_accuracy: 0.8758
# Epoch 13/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0102 - accuracy: 0.8707 - val_loss: 0.0091 - val_accuracy: 0.8764
# Epoch 14/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0102 - accuracy: 0.8707 - val_loss: 0.0103 - val_accuracy: 0.8729
# Epoch 15/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0103 - accuracy: 0.8705 - val_loss: 0.0091 - val_accuracy: 0.8761
# Epoch 16/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0102 - accuracy: 0.8708 - val_loss: 0.0169 - val_accuracy: 0.8582
# Epoch 17/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0101 - accuracy: 0.8710 - val_loss: 0.0092 - val_accuracy: 0.8758
# Epoch 18/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0101 - accuracy: 0.8708 - val_loss: 0.0096 - val_accuracy: 0.8749
# Epoch 19/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0103 - accuracy: 0.8704 - val_loss: 0.0099 - val_accuracy: 0.8746
# Epoch 20/100
# 64800/64800 [==============================] - 6s 89us/sample - loss: 0.0100 - accuracy: 0.8710 - val_loss: 0.0103 - val_accuracy: 0.8733
# Epoch 21/100
# 64800/64800 [==============================] - 6s 89us/sample - loss: 0.0109 - accuracy: 0.8693 - val_loss: 0.0102 - val_accuracy: 0.8737
# Epoch 22/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0104 - accuracy: 0.8702 - val_loss: 0.0096 - val_accuracy: 0.8746
# Epoch 23/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0104 - accuracy: 0.8701 - val_loss: 0.0093 - val_accuracy: 0.8763
# Epoch 24/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0109 - accuracy: 0.8692 - val_loss: 0.0089 - val_accuracy: 0.8764
# Epoch 25/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0102 - accuracy: 0.8706 - val_loss: 0.0093 - val_accuracy: 0.8756
# Epoch 26/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0104 - accuracy: 0.8702 - val_loss: 0.0093 - val_accuracy: 0.8753
# Epoch 27/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0102 - accuracy: 0.8706 - val_loss: 0.0090 - val_accuracy: 0.8764
# Epoch 28/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0099 - accuracy: 0.8712 - val_loss: 0.0447 - val_accuracy: 0.7964
# Epoch 29/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0100 - accuracy: 0.8710 - val_loss: 0.0089 - val_accuracy: 0.8765
# Epoch 30/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0100 - accuracy: 0.8709 - val_loss: 0.0091 - val_accuracy: 0.8760
# Epoch 31/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0099 - accuracy: 0.8711 - val_loss: 0.0090 - val_accuracy: 0.8765
# Epoch 32/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0101 - accuracy: 0.8708 - val_loss: 0.0094 - val_accuracy: 0.8758
# Epoch 33/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0100 - accuracy: 0.8709 - val_loss: 0.0090 - val_accuracy: 0.8765
# Epoch 34/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0100 - accuracy: 0.8710 - val_loss: 0.0090 - val_accuracy: 0.8763
# Epoch 35/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0099 - accuracy: 0.8711 - val_loss: 0.0089 - val_accuracy: 0.8765
# Epoch 36/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0104 - accuracy: 0.8700 - val_loss: 0.0090 - val_accuracy: 0.8764
# Epoch 37/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0102 - accuracy: 0.8704 - val_loss: 0.0096 - val_accuracy: 0.8765
# Epoch 38/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0106 - accuracy: 0.8696 - val_loss: 0.0088 - val_accuracy: 0.8765
# Epoch 39/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0098 - accuracy: 0.8714 - val_loss: 0.0095 - val_accuracy: 0.8744
# Epoch 40/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0103 - accuracy: 0.8702 - val_loss: 0.0097 - val_accuracy: 0.8757
# Epoch 41/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0107 - accuracy: 0.8695 - val_loss: 0.0093 - val_accuracy: 0.8763
# Epoch 42/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0103 - accuracy: 0.8701 - val_loss: 0.0094 - val_accuracy: 0.8754
# Epoch 43/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0106 - accuracy: 0.8697 - val_loss: 0.0090 - val_accuracy: 0.8758
# Epoch 44/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0100 - accuracy: 0.8708 - val_loss: 0.0369 - val_accuracy: 0.8182
# Epoch 45/100
# 64800/64800 [==============================] - 6s 89us/sample - loss: 0.0107 - accuracy: 0.8694 - val_loss: 0.0096 - val_accuracy: 0.8749
# Epoch 46/100
# 64800/64800 [==============================] - 6s 89us/sample - loss: 0.0100 - accuracy: 0.8708 - val_loss: 0.0094 - val_accuracy: 0.8760
# Epoch 47/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0111 - accuracy: 0.8686 - val_loss: 0.0103 - val_accuracy: 0.8731
# Epoch 48/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0100 - accuracy: 0.8708 - val_loss: 0.0089 - val_accuracy: 0.8764
# Epoch 49/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0101 - accuracy: 0.8706 - val_loss: 0.0090 - val_accuracy: 0.8764
# Epoch 50/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0107 - accuracy: 0.8692 - val_loss: 0.0089 - val_accuracy: 0.8757
# Epoch 51/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0111 - accuracy: 0.8685 - val_loss: 0.0108 - val_accuracy: 0.8712
# Epoch 52/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0098 - accuracy: 0.8713 - val_loss: 0.0090 - val_accuracy: 0.8764
# Epoch 53/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0111 - accuracy: 0.8684 - val_loss: 0.0089 - val_accuracy: 0.8764
# Epoch 54/100
# 64800/64800 [==============================] - 6s 88us/sample - loss: 0.0102 - accuracy: 0.8703 - val_loss: 0.0091 - val_accuracy: 0.8758
# Epoch 55/100
# 64800/64800 [==============================] - 5s 84us/sample - loss: 0.0104 - accuracy: 0.8699 - val_loss: 0.0089 - val_accuracy: 0.8765
# Epoch 56/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0105 - accuracy: 0.8696 - val_loss: 0.0089 - val_accuracy: 0.8763
# Epoch 57/100
# 64800/64800 [==============================] - 5s 84us/sample - loss: 0.0108 - accuracy: 0.8692 - val_loss: 0.0093 - val_accuracy: 0.8758
# Epoch 58/100
# 64800/64800 [==============================] - 5s 84us/sample - loss: 0.0105 - accuracy: 0.8696 - val_loss: 0.0093 - val_accuracy: 0.8749
# Epoch 59/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0119 - accuracy: 0.8667 - val_loss: 0.0087 - val_accuracy: 0.8765
# Epoch 60/100
# 64800/64800 [==============================] - 5s 84us/sample - loss: 0.0109 - accuracy: 0.8689 - val_loss: 0.0088 - val_accuracy: 0.8765
# Epoch 61/100
# 64800/64800 [==============================] - 5s 85us/sample - loss: 0.0109 - accuracy: 0.8689 - val_loss: 0.0089 - val_accuracy: 0.8765
# Epoch 62/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0101 - accuracy: 0.8705 - val_loss: 0.0124 - val_accuracy: 0.8689
# Epoch 63/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0102 - accuracy: 0.8701 - val_loss: 0.0087 - val_accuracy: 0.8764
# Epoch 64/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0107 - accuracy: 0.8694 - val_loss: 0.0094 - val_accuracy: 0.8749
# Epoch 65/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0108 - accuracy: 0.8689 - val_loss: 0.0104 - val_accuracy: 0.8726
# Epoch 66/100
# 64800/64800 [==============================] - 5s 85us/sample - loss: 0.0103 - accuracy: 0.8699 - val_loss: 0.0089 - val_accuracy: 0.8761
# Epoch 67/100
# 64800/64800 [==============================] - 5s 85us/sample - loss: 0.0116 - accuracy: 0.8673 - val_loss: 0.0104 - val_accuracy: 0.8731
# Epoch 68/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0147 - accuracy: 0.8612 - val_loss: 0.0088 - val_accuracy: 0.8764
# Epoch 69/100
# 64800/64800 [==============================] - 5s 85us/sample - loss: 0.0126 - accuracy: 0.8655 - val_loss: 0.0094 - val_accuracy: 0.8760
# Epoch 70/100
# 64800/64800 [==============================] - 5s 84us/sample - loss: 0.0134 - accuracy: 0.8637 - val_loss: 0.0088 - val_accuracy: 0.8763
# Epoch 71/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0112 - accuracy: 0.8683 - val_loss: 0.0103 - val_accuracy: 0.8726
# Epoch 72/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0099 - accuracy: 0.8708 - val_loss: 0.0091 - val_accuracy: 0.8761
# Epoch 73/100
# 64800/64800 [==============================] - 5s 84us/sample - loss: 0.0112 - accuracy: 0.8682 - val_loss: 0.0091 - val_accuracy: 0.8757
# Epoch 74/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0119 - accuracy: 0.8667 - val_loss: 0.0089 - val_accuracy: 0.8763
# Epoch 75/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0177 - accuracy: 0.8552 - val_loss: 0.0090 - val_accuracy: 0.8761
# Epoch 76/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0130 - accuracy: 0.8645 - val_loss: 0.0101 - val_accuracy: 0.8736
# Epoch 77/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0140 - accuracy: 0.8624 - val_loss: 0.0097 - val_accuracy: 0.8749
# Epoch 78/100
# 64800/64800 [==============================] - 5s 85us/sample - loss: 0.0101 - accuracy: 0.8704 - val_loss: 0.0093 - val_accuracy: 0.8761
# Epoch 79/100
# 64800/64800 [==============================] - 5s 85us/sample - loss: 0.0112 - accuracy: 0.8683 - val_loss: 0.0090 - val_accuracy: 0.8764
# Epoch 80/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0113 - accuracy: 0.8678 - val_loss: 0.0095 - val_accuracy: 0.8749
# Epoch 81/100
# 64800/64800 [==============================] - 5s 84us/sample - loss: 0.0162 - accuracy: 0.8581 - val_loss: 0.0536 - val_accuracy: 0.7869
# Epoch 82/100
# 64800/64800 [==============================] - 5s 84us/sample - loss: 0.0432 - accuracy: 0.8042 - val_loss: 0.0105 - val_accuracy: 0.8735
# Epoch 83/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0104 - accuracy: 0.8698 - val_loss: 0.0090 - val_accuracy: 0.8765
# Epoch 84/100
# 64800/64800 [==============================] - 6s 87us/sample - loss: 0.0114 - accuracy: 0.8678 - val_loss: 0.0089 - val_accuracy: 0.8763
# Epoch 85/100
# 64800/64800 [==============================] - 5s 84us/sample - loss: 0.0105 - accuracy: 0.8693 - val_loss: 0.0089 - val_accuracy: 0.8765
# Epoch 86/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0099 - accuracy: 0.8707 - val_loss: 0.0093 - val_accuracy: 0.8756
# Epoch 87/100
# 64800/64800 [==============================] - 5s 85us/sample - loss: 0.0120 - accuracy: 0.8666 - val_loss: 0.0097 - val_accuracy: 0.8739
# Epoch 88/100
# 64800/64800 [==============================] - 5s 84us/sample - loss: 0.0102 - accuracy: 0.8701 - val_loss: 0.0090 - val_accuracy: 0.8761
# Epoch 89/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0264 - accuracy: 0.8375 - val_loss: 0.0541 - val_accuracy: 0.7857
# Epoch 90/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0188 - accuracy: 0.8529 - val_loss: 0.0089 - val_accuracy: 0.8760
# Epoch 91/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0116 - accuracy: 0.8673 - val_loss: 0.0115 - val_accuracy: 0.8696
# Epoch 92/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0111 - accuracy: 0.8684 - val_loss: 0.0095 - val_accuracy: 0.8761
# Epoch 93/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0100 - accuracy: 0.8704 - val_loss: 0.0093 - val_accuracy: 0.8756
# Epoch 94/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0183 - accuracy: 0.8539 - val_loss: 0.0089 - val_accuracy: 0.8763
# Epoch 95/100
# 64800/64800 [==============================] - 6s 86us/sample - loss: 0.0150 - accuracy: 0.8604 - val_loss: 0.0088 - val_accuracy: 0.8763
# Epoch 96/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0111 - accuracy: 0.8681 - val_loss: 0.0103 - val_accuracy: 0.8750
# Epoch 97/100
# 64800/64800 [==============================] - 5s 84us/sample - loss: 0.0114 - accuracy: 0.8676 - val_loss: 0.0091 - val_accuracy: 0.8756
# Epoch 98/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0120 - accuracy: 0.8663 - val_loss: 0.0101 - val_accuracy: 0.8733
# Epoch 99/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0122 - accuracy: 0.8660 - val_loss: 0.0089 - val_accuracy: 0.8763
# Epoch 100/100
# 64800/64800 [==============================] - 6s 85us/sample - loss: 0.0121 - accuracy: 0.8663 - val_loss: 0.0090 - val_accuracy: 0.8761
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure()
plt.plot(history.history['accuracy'],'.r', label = 'acc',alpha = 0.3)
plt.plot(history.history['val_accuracy'], '.b', label = 'acc_val',alpha = 0.3)
plt.legend()
plt.grid()

plt.figure()
plt.plot(history.history['loss'],'.r', label = 'loss',alpha = 0.3)
plt.plot(history.history['val_loss'],'.b', label = 'loss_val',alpha = 0.3)
plt.legend()
plt.grid()

# %% [markdown]
# # Predicts

# %%
pred = model.predict(x_test)

# %%
pred_df = pd.DataFrame()
pred_df['pred'] = pred[:,0]
pred_df['y'] = y_test

# %%
pred_df
# Out:
#               pred    y
# 0     1.000000e+00  1.0
# 1     7.786330e-01  0.5
# 2     1.000000e+00  1.0
# 3     1.000000e+00  1.0
# 4     3.378779e-22  0.0
# 5     7.569535e-01  1.0
# 6     1.000000e+00  1.0
# 7     7.488211e-01  0.5
# 8     7.824510e-01  1.0
# 9     1.000000e+00  1.0
# 10    7.868448e-01  1.0
# 11    1.311332e-27  0.0
# 12    1.000000e+00  1.0
# 13    1.000000e+00  1.0
# 14    1.000000e+00  1.0
# 15    1.000000e+00  1.0
# 16    2.267727e-24  0.0
# 17    7.482868e-01  0.5
# 18    2.433306e-17  0.0
# 19    1.000000e+00  1.0
# 20    0.000000e+00  0.0
# 21    1.000000e+00  1.0
# 22    1.000000e+00  1.0
# 23    8.295596e-01  0.5
# 24    8.757127e-01  0.5
# 25    8.284574e-01  1.0
# 26    8.388834e-01  1.0
# 27    1.000000e+00  1.0
# 28    8.128773e-29  0.0
# 29    0.000000e+00  0.0
# ...            ...  ...
# 7970  1.000000e+00  1.0
# 7971  8.606987e-01  0.5
# 7972  8.068303e-01  0.5
# 7973  8.424402e-01  1.0
# 7974  8.335837e-01  1.0
# 7975  7.781495e-01  0.5
# 7976  8.226552e-01  1.0
# 7977  1.000000e+00  1.0
# 7978  8.500245e-01  1.0
# 7979  1.000000e+00  1.0
# 7980  7.599366e-01  1.0
# 7981  0.000000e+00  0.0
# 7982  8.155558e-01  1.0
# 7983  6.563795e-01  1.0
# 7984  1.000000e+00  1.0
# 7985  7.736676e-01  1.0
# 7986  8.093117e-01  1.0
# 7987  1.000000e+00  1.0
# 7988  8.240554e-01  1.0
# 7989  0.000000e+00  0.0
# 7990  9.595637e-19  0.0
# 7991  1.000000e+00  1.0
# 7992  8.055257e-01  1.0
# 7993  1.000000e+00  1.0
# 7994  1.000000e+00  1.0
# 7995  4.174973e-22  0.0
# 7996  5.964702e-13  0.0
# 7997  8.272541e-01  0.5
# 7998  1.709290e-32  0.0
# 7999  1.000000e+00  1.0
#
# [8000 rows x 2 columns]

# %%
def f(x):
    val = x[0]
    if val >= 0.79:
        return win
    if 0.40< val and val < 0.79:
        return draw
    if val <= 0.40:
        return lost

# %%
pred_df['pred'] = pred_df[['pred']].apply(f,axis=1)

# %%
pred_df.count()
# Out:
# pred    8000
# y       8000
# dtype: int64

# %%
# Ver diferença
pred_df[(pred_df['y'] != pred_df['pred']) &(pred_df['y'] == 0)].head(5)
# Out:
#       pred    y
# 3499   0.5  0.0

# %%
pred_df.count()
# Out:
# pred    8000
# y       8000
# dtype: int64

# %%
pred_df[(pred_df['y'] != pred_df['pred']) & (pred_df['y'] == lost)].count()
# O Modelo quase não erra para prever derrotas
# Out:
# pred    1
# y       1
# dtype: int64

# %%
pred_df[(pred_df['y'] != pred_df['pred']) & (pred_df['y'] == win)].count()
# Nem para Vitorias
# Out:
# pred    367
# y       367
# dtype: int64

# %%
pred_df[(pred_df['y'] != pred_df['pred']) & (pred_df['y'] == draw)].count()
# O problema é para valores de empate, ele confunde vitoria com empate
# Out:
# pred    593
# y       593
# dtype: int64

# %%
pred_df
# Out:
#       pred    y
# 0      1.0  1.0
# 1      0.5  0.5
# 2      1.0  1.0
# 3      1.0  1.0
# 4      0.0  0.0
# 5      0.5  1.0
# 6      1.0  1.0
# 7      0.5  0.5
# 8      0.5  1.0
# 9      1.0  1.0
# 10     0.5  1.0
# 11     0.0  0.0
# 12     1.0  1.0
# 13     1.0  1.0
# 14     1.0  1.0
# 15     1.0  1.0
# 16     0.0  0.0
# 17     0.5  0.5
# 18     0.0  0.0
# 19     1.0  1.0
# 20     0.0  0.0
# 21     1.0  1.0
# 22     1.0  1.0
# 23     1.0  0.5
# 24     1.0  0.5
# 25     1.0  1.0
# 26     1.0  1.0
# 27     1.0  1.0
# 28     0.0  0.0
# 29     0.0  0.0
# ...    ...  ...
# 7970   1.0  1.0
# 7971   1.0  0.5
# 7972   1.0  0.5
# 7973   1.0  1.0
# 7974   1.0  1.0
# 7975   0.5  0.5
# 7976   1.0  1.0
# 7977   1.0  1.0
# 7978   1.0  1.0
# 7979   1.0  1.0
# 7980   0.5  1.0
# 7981   0.0  0.0
# 7982   1.0  1.0
# 7983   0.5  1.0
# 7984   1.0  1.0
# 7985   0.5  1.0
# 7986   1.0  1.0
# 7987   1.0  1.0
# 7988   1.0  1.0
# 7989   0.0  0.0
# 7990   0.0  0.0
# 7991   1.0  1.0
# 7992   1.0  1.0
# 7993   1.0  1.0
# 7994   1.0  1.0
# 7995   0.0  0.0
# 7996   0.0  0.0
# 7997   1.0  0.5
# 7998   0.0  0.0
# 7999   1.0  1.0
#
# [8000 rows x 2 columns]

# %%
k = 0
total = len(pred_df['pred'])

for pred,y in zip(pred_df['pred'],y_test[:,0]):
    if pred == y:
        k = k+1
p = k/total
print(f"Porcentagem de Acerto {np.around(p*100,2)}%")
# Out:
# Porcentagem de Acerto 87.99%

# %% [markdown]
# # Save <span style="color:blue">WEIGHT</span>

# %%
#model.save_weights('../save_weight/weight.h5')
