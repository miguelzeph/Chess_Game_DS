# %% [markdown]
# # Starting the Game - V2
#
# ### Update V2
# - Agora serão jogados valores entre 1 a 9 e não mais 0 e 1 para identificar os players
# - A verificação de vitória ou derrota será feita por números **pares / ímpares**
# - Player -> (inicia) = Número ímpar
# - PC -> Número Par
#
#
# #### Motivo:
# - A Máquina precisava saber a sequência das jogadas, e não somente a tabela final do resultado. Se eu não pensar na sequência da jogada, terei de sortear um número, assim não teremos uma inteligência.
#
# #### Futuras Mudanças:
# - <span style='color:red'>TREINAR UM MODELO PARA FAZER A PRIMEIRA JOGADA (ONDE TEMOS MENOS DADOS)
# - <span style='color:red'>Gerar novos dados novamente.... pois treinei errado a rede

# %%
import pandas as pd
import numpy as np
import random

# %%
# creating the table
def df():
    col = []
    for n in range(1,10):
        col.append(n)
    col.append('resultado')

    df = pd.DataFrame(columns=col)
    return df

# %%
def n(x): # even odd function
    
    if x%2 == 0: # Número par retorna 0
        return x%2
    else:# número impar retorna 1
        return x%2

#even_odd(2)

# %%
class ticTacToe():
    
    def __init__(self):
        
        self.df = df()
        self.pos ={
                    1:0.5,
                    2:0.5,
                    3:0.5,
                    4:0.5,
                    5:0.5,
                    6:0.5,
                    7:0.5,
                    8:0.5,
                    9:0.5,
                    'resultado':None }
        self.t = 1 # turnos
    
    def restart_df(self):
        self.df = df()
        
    
    def restart_game(self):
        self.pos ={
                    1:0.5,
                    2:0.5,
                    3:0.5,
                    4:0.5,
                    5:0.5,
                    6:0.5,
                    7:0.5,
                    8:0.5,
                    9:0.5,
                    'resultado':None }
        self.t = 1 # turnos
        
    def check_defeat(self): # player é par
        if n(self.pos[1]) == n(self.pos[2]) == n(self.pos[3]) == 1:
            return 'break'
        if n(self.pos[4]) == n(self.pos[5]) == n(self.pos[6]) == 1:
            return 'break'
        if n(self.pos[1]) == n(self.pos[4]) == n(self.pos[7]) == 1:
            return 'break'
        if n(self.pos[1]) == n(self.pos[5]) == n(self.pos[9]) == 1:
            return 'break'
        if n(self.pos[2]) == n(self.pos[5]) == n(self.pos[8]) == 1:
            return 'break'
        if n(self.pos[3]) == n(self.pos[5]) == n(self.pos[7]) == 1:
            return 'break'
        if n(self.pos[3]) == n(self.pos[6]) == n(self.pos[9]) == 1:
            return 'break'
        if n(self.pos[7]) == n(self.pos[8]) == n(self.pos[9]) == 1:
            return 'break'
        return 'continue'

    def check_victory(self): # pc é impar
        if n(self.pos[1]) == n(self.pos[2]) == n(self.pos[3]) == 0:
            return 'break'
        if n(self.pos[4]) == n(self.pos[5]) == n(self.pos[6]) == 0:
            return 'break'
        if n(self.pos[1]) == n(self.pos[4]) == n(self.pos[7]) == 0:
            return 'break'
        if n(self.pos[1]) == n(self.pos[5]) == n(self.pos[9]) == 0:
            return 'break'
        if n(self.pos[2]) == n(self.pos[5]) == n(self.pos[8]) == 0:
            return 'break'
        if n(self.pos[3]) == n(self.pos[5]) == n(self.pos[7]) == 0:
            return 'break'
        if n(self.pos[3]) == n(self.pos[6]) == n(self.pos[9]) == 0:
            return 'break'
        if n(self.pos[7]) == n(self.pos[8]) == n(self.pos[9]) == 0:
            return 'break'
        return 'continue'
    
    def check_pos_full(self): # EMPATE
        if (self.pos[1] != 0.5 
            and self.pos[2] != 0.5 
            and self.pos[3] != 0.5 
            and self.pos[4] != 0.5
            and self.pos[5] != 0.5
            and self.pos[6] != 0.5
            and self.pos[7] != 0.5
            and self.pos[8] != 0.5
            and self.pos[9] != 0.5):
            
            return 'break'
    
        return 'continue'
    
    # Agora os turnos importam, pois turno impar é player
    # turno par é máquina.
    def check_turn(self):
        if self.t == 10: # Verificar tempo/turnos (f)
            return 'break'
        return 'continue'
    
    # Chamo esse método para verificar tudo
    def check(self):
        
        # Verificar derrota
        if self.check_defeat() == 'break':
            #print('derrotado')
            self.pos['resultado'] = 0
            
            return 'break'
        
        # Verificar Vitoria
        if self.check_victory() == 'break':
            #print('vencedor')
            self.pos['resultado'] = 1
            
            return 'break'
        
        # Verificar Turno
        self.t +=1
        if self.check_turn() == 'break':
            #print('turno')
            self.pos['resultado'] = 0.5 # Empate
            
            return 'break'
        
        # Verificar Tudo
        if self.check_pos_full() == 'break':
            #print('tudo')
            self.pos['resultado'] = 0.5 # Empate
            
            return 'break'
        
        return 'continue'
    
    # Criar a Tabelas e dar appends nela
    def add_value_df(self):
        
        df_receber = pd.DataFrame( columns=list(self.pos.keys()) )
        for i in df_receber.columns:
            if i == 'resultado':
                df_receber[i] = [self.pos[i]]
            else:    
                df_receber[i] = [self.pos[int(i)]]
                
        self.df = self.df.append(df_receber,ignore_index=True)
    
    
    # Aqui eu set os numeros no braço usando INPUTS
    def player(self, player):
        if player == 'player':
            move = int(input('player: '))
            if self.pos[move] == 0.5:
                self.pos[move] = int(self.t)
            else:
                while True:
                    move = int(input('player, tente novamente: '))

                    if self.pos[move] == 0.5:
                        self.pos[move] = int(self.t)
                        break
                        
        if player == 'pc':
            move = int(input('pc: '))
            if self.pos[move] == 0.5:
                self.pos[move] = int(self.t)

            else:
                while True:
                    move = int(input('pc, tente novamente: '))

                    if self.pos[move] == 0.5:
                        self.pos[move] = int(self.t)
                        break
                        
    
    
    def sortear_pos(self): # Ganhar tempo
        livres =[n for n in list(self.pos.keys())[:-1] if list(self.pos.values())[n-1]== 0.5]

        return random.sample(livres,1)[0] # sortear 1 número dentro dos LIVRES
    
    
    
    # Aqui eu uso para deixar a rede Treinar
    def player_random(self, player):
        if player == 'player':
            move = self.sortear_pos()
            if self.pos[move] == 0.5:
                self.pos[move] = int(self.t) # add o valor do turno 
            else:
                while True:
                    move = int(input('player, tente novamente: '))

                    if self.pos[move] == 0.5:
                        self.pos[move] = int(self.t) # add o valor do turno
                        break
                        
        if player == 'pc':
            move = self.sortear_pos()
            if self.pos[move] == 0.5:
                self.pos[move] = int(self.t) # add o valor do turno

            else:
                while True:
                    move = int(input('pc, tente novamente: '))

                    if self.pos[move] == 0.5:
                        self.pos[move] = int(self.t) # add o valor do turno
                        break
    
    
        
    # RUN DE PROGRAM
    def run(self):
        
        while True:
            
            # Jogar Player
            #self.player('player')
            self.player_random('player')
             
            # Check -----------------
            if self.check() == 'break':
                break
            
            
            # Jogar PC
            #self.player('pc')
            self.player_random('pc')
             
            # Check -----------------
            if self.check() == 'break':
                break
            #------------------------
        
        
        self.add_value_df()

# %%
# Iniciar Game
game = ticTacToe()

# %%
for i in range(0,40000):
    game.restart_game()
    game.run()

# %%
game.df
# Out:
#          1    2    3    4    5    6    7    8    9  resultado
# 0        6    7    8    1    5    4    9    2    3        0.5
# 1      0.5    4  0.5    1    3    5  0.5  0.5    2        0.0
# 2      0.5    4  0.5    1    6  0.5    3    2    5        1.0
# 3        2  0.5  0.5    5    1    7    6    3    4        0.0
# 4      0.5    1  0.5    2    3  0.5    4    5  0.5        0.0
# 5        6    1    9    7    3    8    2    4    5        0.5
# 6        8    5    1    7    2    3    6    4    9        0.0
# 7        3  0.5    6  0.5    2    5    4  0.5    1        1.0
# 8      0.5    2    1    3    8    5    7    6    4        1.0
# 9        2    3  0.5    6  0.5    1    4    5  0.5        1.0
# 10       2  0.5    1    5    6  0.5  0.5    3    4        1.0
# 11       3    4    6    2    7  0.5  0.5    5    1        0.0
# 12       9    5    8    4    3    7    2    6    1        0.0
# 13     0.5    6    7    4    5  0.5    1    2    3        0.0
# 14       6    1    7    8    9    2    5    4    3        0.0
# 15       6    4    1    2  0.5    3    5  0.5    7        0.0
# 16       2    8    3    5    9    6    1    7    4        0.0
# 17       6  0.5    1    3    2    7    4    5    8        1.0
# 18       3    9    4    8    1    7    6    5    2        0.0
# 19       6    3    5  0.5    1    2    4    7  0.5        0.0
# 20       5    1    7    4  0.5    3  0.5    2    6        0.0
# 21       2  0.5    1    4    5  0.5    6  0.5    3        1.0
# 22       5  0.5  0.5    1  0.5    3    2    4    6        1.0
# 23       5    6    1    2    9    8    7    3    4        0.0
# 24       5    3  0.5    8    4    6    2    7    1        1.0
# 25       5    4    6    1    3    2    7  0.5  0.5        0.0
# 26       5    1    3  0.5  0.5  0.5    4    2  0.5        0.0
# 27     0.5  0.5    1    4    2    3  0.5  0.5    5        0.0
# 28       4    7    5    6    3  0.5    8    2    1        1.0
# 29       6  0.5    3  0.5    2  0.5    1    5    4        1.0
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...        ...
# 39970    3    2    1  0.5    7    4    6  0.5    5        0.0
# 39971    2  0.5    5    4  0.5    3    6    1  0.5        1.0
# 39972    7    4    2  0.5    5  0.5    3    6    1        0.0
# 39973    4    3    2    1    5    6    7  0.5    8        1.0
# 39974    2    3  0.5  0.5    7    4    5    1    6        0.0
# 39975    4    6    3    8    7    1    9    5    2        0.0
# 39976    3    4    8    9    7    5    1    6    2        0.0
# 39977    4    5  0.5    1    2    3  0.5  0.5    6        1.0
# 39978    9    3    8    2    6    5    7    1    4        0.5
# 39979    1    2    3    9    6    4    7    5    8        0.0
# 39980    5  0.5    4    2    3  0.5  0.5  0.5    1        0.0
# 39981    2    5    6    8    9    7    1    3    4        0.0
# 39982  0.5    5    1    6    2    4  0.5    3  0.5        1.0
# 39983    7    4    2    5    6    3    9    1    8        0.0
# 39984    1    9    3    4    8    7    5    6    2        0.0
# 39985  0.5    1    3    2    5    7    6    8    4        1.0
# 39986    4    2    6    5    1  0.5    3  0.5  0.5        1.0
# 39987    6    1  0.5  0.5    4    5    3  0.5    2        1.0
# 39988    1    5    3  0.5    2  0.5  0.5  0.5    4        0.0
# 39989    8    2    6  0.5    7    3    5    1    4        1.0
# 39990    6    3    7    2    1    8    9    4    5        0.0
# 39991    3    7    6    4    2    1    5    9    8        0.5
# 39992  0.5    1    7    4    3  0.5    5    6    2        0.0
# 39993    6    2    4    1  0.5    5    3  0.5  0.5        1.0
# 39994    7    1    3    6  0.5    5  0.5    2    4        0.0
# 39995    5    1    6    4  0.5    8    3    7    2        1.0
# 39996  0.5    2    1    3    4    5    7    8    6        1.0
# 39997    8    2    6    5    1    4    3    7  0.5        1.0
# 39998    6    5    8    4    2    7    1    9    3        0.0
# 39999    8    7    5    9    6    2    1    4    3        0.5
#
# [40000 rows x 10 columns]

# %%
# Save TABLE
game.df.to_pickle('./dados.pkl')

# %%
#load_df = pd.read_pickle('./dados.pkl')

# %%
#load_df.drop_duplicates().reset_index().drop('index',axis=1)

# %%
# Remover Valores duplicados
dub = game.df.drop_duplicates().reset_index().drop('index',axis=1)
dub.tail()
# Out:
#          1  2  3  4    5  6  7  8    9  resultado
# 34407    5  1  6  4  0.5  8  3  7    2        1.0
# 34408  0.5  2  1  3    4  5  7  8    6        1.0
# 34409    8  2  6  5    1  4  3  7  0.5        1.0
# 34410    6  5  8  4    2  7  1  9    3        0.0
# 34411    8  7  5  9    6  2  1  4    3        0.5
